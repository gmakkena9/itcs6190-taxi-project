# %% [markdown]
# # Stage 1 — Ingestion
#
# Reads the raw CSV with an explicit schema and writes curated Parquet.
#
# The implementation lives in `src/ingestion.py`. This notebook just runs it.

# %%
import sys; sys.path.insert(0, '../src')
import ingestion
ingestion.run()
