# %% [markdown]
# # Stage 3 — Structured Streaming
#
# Streams micro-batched trip files and aggregates demand per pickup hour.
#
# The implementation lives in `src/streaming.py`. This notebook just runs it.

# %%
import sys; sys.path.insert(0, '../src')
import streaming
streaming.run()
