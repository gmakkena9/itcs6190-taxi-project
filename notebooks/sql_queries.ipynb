# %% [markdown]
# # Stage 2 — Transformations & Spark SQL
#
# Cleans, engineers features, joins zones, and runs the Spark SQL demand aggregations.
#
# The implementation lives in `src/transformations.py`. This notebook just runs it.

# %%
import sys; sys.path.insert(0, '../src')
import transformations
transformations.run()
