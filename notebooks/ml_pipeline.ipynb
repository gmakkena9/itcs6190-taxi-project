# %% [markdown]
# # Stage 4 — MLlib Regression
#
# Trains the trip-duration regression pipeline and reports RMSE/MAE/R².
#
# The implementation lives in `src/ml_pipeline.py`. This notebook just runs it.

# %%
import sys; sys.path.insert(0, '../src')
import ml_pipeline
ml_pipeline.run()
